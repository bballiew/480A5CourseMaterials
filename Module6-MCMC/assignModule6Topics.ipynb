# %%
import sys
import os
sys.path.append(os.path.abspath('BIOM480A5'))
from BIOM480A5_codes import spring2025Students, MCMCExamples
import textwrap

import random

# %%
# set rng seed for reproducibility
random.seed(0)
students = spring2025Students()
topics = MCMCExamples()
random.shuffle(topics)

# %%
assignmentDict = {}
for student in students:
    assignmentDict[student] = topics.pop()

print("Assignment for Spring 2025 students")
for student, topic in assignmentDict.items():
    # Print the folllowing string, wrap the output at 80 characters
    string2print = f"{student} will present on the topic of {topic}"
    print(textwrap.fill(string2print, width=80))
    print('\n')
# Out:
# Assignment for Spring 2025 students
# Becca B will present on the topic of Model-based Bayesian adaptive trial design
#
#
# Ella B will present on the topic of Bayesian deconvolution of fluorescent
# microscopy data
#
#
# Lauren B will present on the topic of Haplotype inference from genotypic data
#
#
# James B will present on the topic of Parameter inference for nonlinear ODE
# models of gene circuits
#
#
# Chayanee C will present on the topic of Estimating parameters in adsorption
# isotherm models
#
#
# Deven D will present on the topic of Bayesian design of experiments for
# catalytic systems
#
#
# Jackson E will present on the topic of Quantitative PET imaging with Bayesian
# hierarchical modeling
#
#
# Delaney E will present on the topic of Using MCMC to identify bistability in
# gene regulatory networks
#
#
# Christian F will present on the topic of Inferring reaction rate constants from
# reactor output using MCMC
#
#
# Lillian G will present on the topic of Inferring connectivity in neural circuits
# from spike train data
#
#
# Andy G will present on the topic of Estimating parameters in metabolic network
# models with flux data
#
#
# Emma G will present on the topic of Probabilistic segmentation of organs in
# medical images
#
#
# Nick G will present on the topic of Deconvolving bulk RNA-seq into cell-type
# proportions
#
#
# Joshua H will present on the topic of Bayesian optimization of microbial strain
# design
#
#
# Paycen H will present on the topic of Identifying genomic regions under
# selection in evolution experiments
#
#
# Kyle H will present on the topic of Inferring latent variables in scRNA-seq
# using Bayesian autoencoders
#
#
# Emma H will present on the topic of Inferring diffusion coefficients in porous
# media
#
#
# Elijah J will present on the topic of Estimating phylogenetic trees and
# divergence times
#
#
# Gabriela J will present on the topic of Inferring Monod parameters from batch
# fermentation data
#
#
# Addison L will present on the topic of Bayesian clustering of single-cell RNA-
# seq data
#
#
# Matthew L will present on the topic of Bayesian inference of allosteric
# regulation mechanisms
#
#
# Hassan M will present on the topic of Bayesian meta-analysis of treatment
# efficacy across clinical trials
#
#
# Bella P will present on the topic of Bayesian control strategies for continuous
# biomanufacturing
#
#
# Chris RT will present on the topic of Inferring under-reporting rates in
# COVID-19 or other outbreaks
#
#
# Mariana S will present on the topic of Modeling yield variability in bioreactors
# using hierarchical models
#
#
# Dylan S will present on the topic of Modeling EEG/MEG sources using hierarchical
# Bayesian models
#
#
# Jacob S will present on the topic of Detecting change points in neural firing
# patterns
#
#
# Hayley S will present on the topic of Estimating neural tuning curves with
# Bayesian regression
#
#
# Kayla T will present on the topic of Calling copy number variations in cancer
# genomes
#
#
# Vivia VDM will present on the topic of Inferring transcription factor binding
# kinetics from ChIP-seq
#
#
# Fig V will present on the topic of Bayesian SIR model fitting to epidemic
# outbreak data
#
#
# AbbyMae W will present on the topic of Detecting differential gene expression
# with low-count RNA-seq data
#
#
# Alvina Y will present on the topic of Bayesian calibration of process simulators
# in chemical manufacturing
#
#
# Polina Z will present on the topic of Parameter inference for biomass growth
# under uncertainty
